# %%
# %run /Shared/Functions_and_Parameters/Application_Functions

# %%
#My_main_program:
def main():
    #path:
    connection_input_path = '/mnt/bronze/Source_Files/simconnection.parquet'
    #Read source date
    connection_source_data = read_connection_data_from_file(connection_input_path)
    #Data Transformations
    connection_transformed_data = connection_valid_transformation(connection_source_data)

if __name__ == "__main__":
    main()

# %%
# %sql
convert to delta parquet.`/mnt/silver/Valid_Files/valid_simconnection`
